# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
df['Species'] = encoder.fit_transform(df['Species'])

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
df = df[df['Species'] != 0][['SepalWidthCm','PetalLengthCm','Species']]

# %%
df.head()
# Out:
#     SepalWidthCm  PetalLengthCm  Species
# 50           3.2            4.7        1
# 51           3.2            4.5        1
# 52           3.1            4.9        1
# 53           2.3            4.0        1
# 54           2.8            4.6        1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
pip install  matplotlib.backends.registry
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\rosha\anaconda3\Lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement matplotlib.backends.registry (from versions: none)
# ERROR: No matching distribution found for matplotlib.backends.registry

# %%
plt.scatter(df['SepalWidthCm'],df['PetalLengthCm'],c=df['Species'],cmap='winter')

# %%
df_train = df.iloc[:60,:].sample(10)
df_train
# Out:
#      SepalWidthCm  PetalLengthCm  Species
# 67            2.7            4.1        1
# 75            3.0            4.4        1
# 96            2.9            4.2        1
# 99            2.8            4.1        1
# 106           2.5            4.5        2
# 102           3.0            5.9        2
# 81            2.4            3.7        1
# 72            2.5            4.9        1
# 92            2.6            4.0        1
# 86            3.1            4.7        1

# %%
# Taking only 10 rows for training
df = df.sample(100)
df_train = df.iloc[:60,:].sample(10) # first 60 me se 10 random data nikal  liye and traning data
df_val = df.iloc[60:80,:].sample(5) # valdiation 
df_test = df.iloc[80:,:].sample(5)  # testing data

# %%
df_train
# Out:
#      SepalWidthCm  PetalLengthCm  Species
# 68            2.2            4.5        1
# 51            3.2            4.5        1
# 71            2.8            4.0        1
# 135           3.0            6.1        2
# 89            2.5            4.0        1
# 88            3.0            4.1        1
# 144           3.3            5.7        2
# 149           3.0            5.1        2
# 77            3.0            5.0        1
# 91            3.0            4.6        1

# %%
df_val
# Out:
#      SepalWidthCm  PetalLengthCm  Species
# 105           3.0            6.6        2
# 129           3.0            5.8        2
# 62            2.2            4.0        1
# 66            3.0            4.5        1
# 50            3.2            4.7        1

# %%
df_test
# Out:
#      SepalWidthCm  PetalLengthCm  Species
# 103           2.9            5.6        2
# 99            2.8            4.1        1
# 100           3.3            6.0        2
# 107           2.9            6.3        2
# 139           3.1            5.4        2

# %%
X_test = df_val.iloc[:,0:2].values
y_test = df_val.iloc[:,-1].values

# %%
y_test
# Out:
# array([2, 2, 1, 1, 1])

# %% [markdown]
# # Case 1 - Bagging

# %%
# Data for Tree 1
df_bag = df_train.sample(8,replace=True)

X = df_bag.iloc[:,0:2]
y = df_bag.iloc[:,-1]

df_bag
# Out:
#      SepalWidthCm  PetalLengthCm  Species
# 51            3.2            4.5        1
# 77            3.0            5.0        1
# 149           3.0            5.1        2
# 68            2.2            4.5        1
# 149           3.0            5.1        2
# 135           3.0            6.1        2
# 89            2.5            4.0        1
# 51            3.2            4.5        1

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from mlxtend.plotting import plot_decision_regions
from sklearn.metrics import accuracy_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 3
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 from sklearn.tree import plot_tree
# ----> 3 from mlxtend.plotting import plot_decision_regions
#       4 from sklearn.metrics import accuracy_score
#
# ModuleNotFoundError: No module named 'mlxtend'

# %%
python -m pip install mlxtend
# Out:
#   Cell In[55], line 1
#     python -m pip install mlxtend
#               ^
# SyntaxError: invalid syntax

# %%
dt_bag1 = DecisionTreeClassifier()

# %%
evaluate(dt_bag1,X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 evaluate(dt_bag1,X,y)
#
# NameError: name 'evaluate' is not defined

# %%
# Data for Tree 1
df_bag = df_train.sample(8,replace=True)

# Fetch X and y
X = df_bag.iloc[:,0:2]
y = df_bag.iloc[:,-1]

# print df_bag
df_bag
# Out:
#      SepalWidthCm  PetalLengthCm  Species
# 129           3.0            5.8        2
# 132           2.8            5.6        2
# 129           3.0            5.8        2
# 97            2.9            4.3        1
# 146           2.5            5.0        2
# 129           3.0            5.8        2
# 52            3.1            4.9        1
# 146           2.5            5.0        2

# %%
dt_bag2 = DecisionTreeClassifier()
evaluate(dt_bag2,X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 dt_bag2 = DecisionTreeClassifier()
# ----> 2 evaluate(dt_bag2,X,y)
#
# NameError: name 'evaluate' is not defined

# %%
# Data for Tree 1
df_bag = df_train.sample(8,replace=True)

# Fetch X and y
X = df_bag.iloc[:,0:2]
y = df_bag.iloc[:,-1]

# print df_bag
df_bag
# Out:
#      SepalWidthCm  PetalLengthCm  Species
# 132           2.8            5.6        2
# 52            3.1            4.9        1
# 132           2.8            5.6        2
# 146           2.5            5.0        2
# 136           3.4            5.6        2
# 52            3.1            4.9        1
# 51            3.2            4.5        1
# 129           3.0            5.8        2

# %%
dt_bag3 = DecisionTreeClassifier()
evaluate(dt_bag3,X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 dt_bag3 = DecisionTreeClassifier()
# ----> 2 evaluate(dt_bag3,X,y)
#
# NameError: name 'evaluate' is not defined

# %%
def evaluate(clf,X,y):
    clf.fit(X,y)
    plot_tree(clf)
    plt.show()
    plot_decision_regions(X.values, y.values, clf=clf, legend=2)
    y_pred = clf.predict(X_test)
    print(accuracy_score(y_test,y_pred))

# %% [markdown]
# ## Predict

# %%
df_test
# Out:
#      SepalWidthCm  PetalLengthCm  Species
# 119           2.2            5.0        2
# 67            2.7            4.1        1
# 114           2.8            5.1        2
# 68            2.2            4.5        1
# 104           3.0            5.8        2

# %%
print("Predictor 1",dt_bag1.predict(np.array([2.2,5.0]).reshape(1,2)))
print("Predictor 2",dt_bag2.predict(np.array([2.2,5.0]).reshape(1,2)))
print("Predictor 3",dt_bag3.predict(np.array([2.2,5.0]).reshape(1,2)))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 print("Predictor 1",dt_bag1.predict(np.array([2.2,5.0]).reshape(1,2)))
#       2 print("Predictor 2",dt_bag2.predict(np.array([2.2,5.0]).reshape(1,2)))
#       3 print("Predictor 3",dt_bag3.predict(np.array([2.2,5.0]).reshape(1,2)))
#
# File d:\Machine learning restart\venv\Lib\site-packages\sklearn\tree\_classes.py:532, in BaseDecisionTree.predict(self, X, check_input)
#     509 def predict(self, X, check_input=True):
#     510     """Predict class or regression value for X.
#     511
#     512     For a classification model, the predicted class for each sample in X is
#    (...)    530         The predicted classes, or the predict values.
#     531     """
# --> 532     check_is_fitted(self)
#     533     X = self._validate_X_predict(X, check_input)
#     534     proba = self.tree_.predict(X)
#
# ...

# %% [markdown]
# # Pasting

# %%
# Row sampling without replacement
df_train
# Out:
#      SepalWidthCm  PetalLengthCm  Species
# 122           2.8            6.7        2
# 131           3.8            6.4        2
# 137           3.1            5.5        2
# 130           2.8            6.1        2
# 145           3.0            5.2        2
# 52            3.1            4.9        1
# 96            2.9            4.2        1
# 75            3.0            4.4        1
# 100           3.3            6.0        2
# 53            2.3            4.0        1

# %%
df_train.sample(8)
# Out:
#      SepalWidthCm  PetalLengthCm  Species
# 131           3.8            6.4        2
# 52            3.1            4.9        1
# 122           2.8            6.7        2
# 130           2.8            6.1        2
# 53            2.3            4.0        1
# 96            2.9            4.2        1
# 145           3.0            5.2        2
# 75            3.0            4.4        1

# %% [markdown]
# # Random Subspaces

# %%
df1 = pd.read_csv('Iris.csv')
df1 = df1.sample(10)

# %%
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 51    52            6.4           3.2            4.5           1.5
# 108  109            6.7           2.5            5.8           1.8
# 133  134            6.3           2.8            5.1           1.5
# 22    23            4.6           3.6            1.0           0.2
# 71    72            6.1           2.8            4.0           1.3
# 84    85            5.4           3.0            4.5           1.5
# 148  149            6.2           3.4            5.4           2.3
# 104  105            6.5           3.0            5.8           2.2
# 127  128            6.1           3.0            4.9           1.8
# 94    95            5.6           2.7            4.2           1.3
#
#              Species
# 51   Iris-versicolor
# 108   Iris-virginica
# 133   Iris-virginica
# 22       Iris-setosa
# 71   Iris-versicolor
# 84   Iris-versicolor
# 148   Iris-virginica
# 104   Iris-virginica
# 127   Iris-virginica
# ...

# %%
df1.sample(2,replace=True,axis=1)  # omly column is repated and row is not repeated.
# Out:
#      PetalWidthCm  PetalWidthCm
# 51            1.5           1.5
# 108           1.8           1.8
# 133           1.5           1.5
# 22            0.2           0.2
# 71            1.3           1.3
# 84            1.5           1.5
# 148           2.3           2.3
# 104           2.2           2.2
# 127           1.8           1.8
# 94            1.3           1.3

# %% [markdown]
# # Random Patches
# - Row sampling and column sampling both is doing

# %%
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 51    52            6.4           3.2            4.5           1.5
# 108  109            6.7           2.5            5.8           1.8
# 133  134            6.3           2.8            5.1           1.5
# 22    23            4.6           3.6            1.0           0.2
# 71    72            6.1           2.8            4.0           1.3
# 84    85            5.4           3.0            4.5           1.5
# 148  149            6.2           3.4            5.4           2.3
# 104  105            6.5           3.0            5.8           2.2
# 127  128            6.1           3.0            4.9           1.8
# 94    95            5.6           2.7            4.2           1.3
#
#              Species
# 51   Iris-versicolor
# 108   Iris-virginica
# 133   Iris-virginica
# 22       Iris-setosa
# 71   Iris-versicolor
# 84   Iris-versicolor
# 148   Iris-virginica
# 104   Iris-virginica
# 127   Iris-virginica
# ...

# %%
df1.sample(8,replace=True).sample(2,replace=True,axis=1) # first sample is row sampling and second sampling is column sampling
# Out:
#      SepalWidthCm  SepalWidthCm
# 94            2.7           2.7
# 127           3.0           3.0
# 104           3.0           3.0
# 133           2.8           2.8
# 148           3.4           3.4
# 84            3.0           3.0
# 71            2.8           2.8
# 108           2.5           2.5
