# %%
import pickle # it is for load data or saved models
import numpy as np # used to create input array

# %%
pipe = pickle.load(open('pipe.pkl','rb'))  # pipe.pkl :-  it contain imputer,encoder,scaler,ml model
# Out:
# c:\Users\rosha\anaconda3\Lib\site-packages\sklearn\base.py:380: InconsistentVersionWarning: Trying to unpickle estimator SimpleImputer from version 0.23.1 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\rosha\anaconda3\Lib\site-packages\sklearn\base.py:380: InconsistentVersionWarning: Trying to unpickle estimator ColumnTransformer from version 0.23.1 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
# Assume user input
test_input2 = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# %% [markdown]
# # Pipeline automatically:
#
# - Handles missing values
#
# - Encodes categorical columns
#
# - Scales numeric columns
#
# - Applies trained ML model

# %%
pipe.predict(test_input2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pipe.predict(test_input2)
#
# NameError: name 'pipe' is not defined
